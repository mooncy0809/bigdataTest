# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# 1. 제1 유형: 문제 1
# BostonHousing 데이터 세트 이용
# crim 항목의 상위에서 10번째 값(즉, 상위 10번째 값 중에서 가장 적은 값)으로 상위 10개의 값을 변환하고,
# age가 80이상인 값에 대하여 crim 평균을 구하시오. answer: 5.759386624999999
from sklearn.datasets import load_boston

# %%
boston=load_boston()

# %%
df=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
df.sort_values('CRIM',ascending=False,inplace=True)

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  88.97620   0.0  18.10   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 418  73.53410   0.0  18.10   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 405  67.92080   0.0  18.10   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 414  45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 55    0.01311  90.0   1.22   0.0  0.403  7.249   21.9  8.6966   5.0  226.0
# 341   0.01301  35.0   1.52   0.0  0.442  7.241   49.3  7.0379   1.0  284.0
# 285   0.01096  55.0   2.25   0.0  0.389  6.453   31.9  7.3073   1.0  300.0
# 284   0.00906  90.0   2.97   0.0  0.400  7.088   20.8  7.3073   1.0  285.0
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
#
#      PTRATIO       B  LSTAT
# 380     20.2  396.90  17.21
# ...

# %%
df2=df.head(10)
df2
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  88.9762  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 418  73.5341  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  51.1358  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 414  45.7461  0.0   18.1   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 404  41.5292  0.0   18.1   0.0  0.693  5.531   85.4  1.6074  24.0  666.0
# 398  38.3518  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 427  37.6619  0.0   18.1   0.0  0.679  6.202   78.7  1.8629  24.0  666.0
# 413  28.6558  0.0   18.1   0.0  0.597  5.155  100.0  1.5894  24.0  666.0
# 417  25.9406  0.0   18.1   0.0  0.679  5.304   89.1  1.6475  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 380     20.2  396.90  17.21
# 418     20.2   16.45  20.62
# 405     20.2  384.97  22.98
# 410     20.2    2.60  10.11
# ...

# %%
minimum=df2['CRIM'].min()

# %%
df.iloc[0:9,0]=minimum

# %%
df.head(11)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 380  25.9406  0.0   18.1   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 418  25.9406  0.0   18.1   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
# 405  25.9406  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
# 410  25.9406  0.0   18.1   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 414  25.9406  0.0   18.1   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 404  25.9406  0.0   18.1   0.0  0.693  5.531   85.4  1.6074  24.0  666.0
# 398  25.9406  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 427  25.9406  0.0   18.1   0.0  0.679  6.202   78.7  1.8629  24.0  666.0
# 413  25.9406  0.0   18.1   0.0  0.597  5.155  100.0  1.5894  24.0  666.0
# 417  25.9406  0.0   18.1   0.0  0.679  5.304   89.1  1.6475  24.0  666.0
# 400  25.0461  0.0   18.1   0.0  0.693  5.987  100.0  1.5888  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 380     20.2  396.90  17.21
# 418     20.2   16.45  20.62
# ...

# %%
df[df['AGE']>=80]['CRIM'].mean()
# Out:
# 5.759386624999999

# %%
# 2. 제1 유형: 문제 2 housing.csv
# 주어진 데이터 첫 번째 행부터 순서대로 80%까지의 데이터를 훈련 데이터로 추출 후
# train 데이터에서 'total_bedrooms' 변수의 결측값(NaN)을 'total_bedrooms' 변수의 중앙값으로 대체하고,
# 대체전의 'total_bedrooms' 변수 표준편차 값과
# 대체 후의 'total_bedrooms'변수 표준편차 값을 산출한다. 
# 변환 이전과 이후의 표준편차 차이를 구하시오. ./data/housing.csv   answer: 1.975147

# %%
df=pd.read_csv('./data/housing.csv')

# %%
# 주어진 데이터 첫 번째 행부터 순서대로 80%까지의 데이터를 훈련 데이터로 추출 후
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.2,shuffle=False)

# %%
train_org=train.copy()
train_org
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.11     37.74                11.0       3886.0           599.0
# 16508    -121.10     37.80                35.0       1853.0           331.0
# 16509    -121.11     37.76                22.0       2606.0           411.0
# 16510    -121.16     37.73                 7.0       4956.0           941.0
# 16511    -121.25     37.76                22.0       2430.0           417.0
#
# ...

# %%
# train 데이터에서 'total_bedrooms' 변수의 결측값(NaN)을 'total_bedrooms' 변수의 중앙값으로 대체하고,
mid=train['total_bedrooms'].median()

# %%
print(mid)
# Out:
# 436.0

# %%
train['total_bedrooms'].fillna(mid,inplace=True)

# %%
print(train.isna().sum())
print(train_org.isna().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        159
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
std1=train_org['total_bedrooms'].std()
std1
# Out:
# 435.900577052527

# %%
std2=train['total_bedrooms'].std()
std2
# Out:
# 433.9254297608813

# %%
abs(std1-std2)
# Out:
# 1.975147291645726

# %%
# 3. 제1 유형: 문제 3 insurance.csv
#    다음은 Insurance 데이터 세트이다. charges 항목에서 이상값의 합을 구하시오.
#    (이상값은 평균에서 1.5 표준편차 이상인 값) ./data/insurance.csv  answer: 6421430

# %%
df=pd.read_csv('./data/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
lower=df['charges'].mean()-1.5*df['charges'].std()

# %%
upper=df['charges'].mean()+1.5*df['charges'].std()

# %%
print(int(df[(df['charges']<lower)|(df['charges']>upper)]['charges'].sum()))
# Out:
# 6421430

# %%
# 4. 아래와 같이 주어진 airquality  데이터 세트에서 Solar.R에 결측값이 있는 행을 제거하고, airquality.csv
#    Ozone 항목의 결측값을 중앙값으로 대체한 후
#    중앙값으로 대체하기 이전과 이후의 Ozone의 표준편차의 차이를 구하시오. 소수점 5번째 자리까지 나타내도록 반올림
#    데이터: https://forge.scilab.org/7index.php/p/rdataset/source/tree/master/csv/datasets/airquality.csv
#    ./data/airquality.csv   answer: 3.90557

# %%
df=pd.read_csv('./data/airquality.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
df.dropna(subset=['Solar.R'],inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         35
# Solar.R        0
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
df_org=df.copy()

# %%
df['Ozone'].fillna(df['Ozone'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
round(abs(df_org['Ozone'].std()-df['Ozone'].std()),5)
# Out:
# 3.90557

# %%
# 5. 다음과 같이 Hitters 데이터 세트가 주어졌을 때, Salary의 이상값의 합을 구하시오. hitters.csv
#    (단, 이상값은 중위수에서 IQR의 2배를 초과하는 값으로 한다.) Hitters{ISLR} answer: 21671.86

# %%
df=pd.read_csv('./data/hitters.csv')

# %%
df.head(3)
# Out:
#        Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# 0  -Andy Allanson    293    66      1    30   29     14      1     293     66
# 1     -Alan Ashby    315    81      7    24   38     39     14    3449    835
# 2    -Alvin Davis    479   130     18    66   72     76      3    1624    457
#
#    ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  Salary  \
# 0  ...     30    29      14       A        E     446       33      20     NaN
# 1  ...    321   414     375       N        W     632       43      10   475.0
# 2  ...    224   266     263       A        W     880       82      14   480.0
#
#    NewLeague
# 0          A
# 1          N
# 2          A
#
# [3 rows x 21 columns]

# %%
df.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   380.928571  101.024845   10.770186   50.909938   48.027950   38.742236
# std    153.404981   46.454741    8.709037   26.024095   26.166895   21.639327
# min     16.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    255.250000   64.000000    4.000000   30.250000   28.000000   22.000000
# 50%    379.500000   96.000000    8.000000   48.000000   44.000000   35.000000
# 75%    512.000000  137.000000   16.000000   69.000000   64.750000   53.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years       CAtBat        CHits      CHmRun        CRuns  \
# count  322.000000    322.00000   322.000000  322.000000   322.000000
# mean     7.444099   2648.68323   717.571429   69.490683   358.795031
# ...

# %%
iqr=df['Salary'].quantile(q=0.75)-df['Salary'].quantile(q=0.25)
print(iqr)
# Out:
# 560.0

# %%
upper=df['Salary'].median()+2*iqr

# %%
df[df['Salary']>upper]['Salary'].sum()
# Out:
# 21671.864

# %%
# 6. 주어진 Diamonds의 데이터를 순서대로 80% 데이터를 훈련 데이터로 만들어서 diamonds.csv
#    price 기준으로 상위 100개의
#    데이터에 대한 price 평균을 구하시오. diamonds.csv  answer: 18663.33

# %%
df=pd.read_csv('./data/diamonds.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.2,shuffle=False)

# %%
train.sort_values('price',ascending=False,inplace=True)
train
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
#
# [43152 rows x 10 columns]

# %%
temp=train.head(100)

# %%
temp['price'].mean()
# Out:
# 18663.33

# %%
# 7. 다음은 뉴욕의 공기 오염을 측정한 airquality 데이터 세트이다. airquality.csv
#    데이터의 순서대로 90% 데이터를 훈련 데이터로 추출하고
#    Ozone 항목의 결측값을 평균으로 변경한 후 변경전,후의 중앙값의 차이를 구하시오. answer: 10.36634
#    데이터: https://forge.scilab.org/7index.php/p/rdataset/source/tree/master/csv/datasets/airquality.csv
#    ./data/airquality.csv

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('./data/airquality.csv')

# %%
train,test=train_test_split(df,test_size=0.1,shuffle=False)

# %%
train_org=train.copy()

# %%
train_org.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         36
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
train['Ozone'].fillna(train['Ozone'].mean(),inplace=True)

# %%
train.isna().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
print(round(abs(train_org['Ozone'].median()-train['Ozone'].median()),5))
# Out:
# 10.36634

# %%
# 8. 다음은 music 데이터 세트이다.airquality.csv
#    정렬된 tempo 항목의 상위 25%와 하위 25%를 0으로 대체하여 훈련 데이터를 생성하고 
#    tempo 항목의 평균과 표준편차의 합을 구하시오. music.csv  R answer: 116.9999  Python answer: 116.92620848615249

# %%
df=pd.read_csv('./data/music.csv')

# %%
df
# Out:
#            filename       tempo  beats  chroma_stft      rmse  \
# 0    blues.00081.au  103.359375     50     0.380260  0.248262
# 1    blues.00022.au   95.703125     44     0.306451  0.113475
# 2    blues.00031.au  151.999081     75     0.253487  0.151571
# 3    blues.00012.au  184.570312     91     0.269320  0.119072
# 4    blues.00056.au  161.499023     74     0.391059  0.137728
# ..              ...         ...    ...          ...       ...
# 995   rock.00017.au  123.046875     59     0.418812  0.166056
# 996   rock.00081.au  117.453835     56     0.335774  0.093676
# 997   rock.00004.au  103.359375     45     0.372834  0.208743
# 998   rock.00006.au  112.347147     45     0.344472  0.180163
# 999   rock.00066.au   75.999540     36     0.360098  0.042995
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0          2116.942959         1956.611056  4196.107960            0.127272
# ...

# %%
df.sort_values('tempo',inplace=True)
df
# Out:
#                filename       tempo  beats  chroma_stft      rmse  \
# 578       jazz.00089.au   54.978391     25     0.280358  0.045045
# 10       blues.00093.au   58.726918     26     0.377690  0.065906
# 787        pop.00049.au   58.726918     28     0.322574  0.147505
# 278    country.00061.au   60.092660     30     0.314423  0.107209
# 577       jazz.00007.au   61.523438     28     0.197231  0.093770
# ..                  ...         ...    ...          ...       ...
# 167  classical.00053.au  215.332031     95     0.304578  0.139884
# 508       jazz.00030.au  215.332031    102     0.235051  0.029619
# 743        pop.00076.au  215.332031    109     0.475726  0.245391
# 505       jazz.00017.au  215.332031    105     0.345524  0.049864
# 188  classical.00009.au  234.907670    117     0.270478  0.023798
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 578        1787.800681         2485.583898  3905.418051            0.062758
# ...

# %%
per25=round(df.shape[0]*0.25)

# %%
per75=round(df.shape[0]*0.75)

# %%
print(per25,per75)
# Out:
# 250 750

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                filename       tempo  beats  chroma_stft      rmse  \
# 0         jazz.00089.au   54.978391     25     0.280358  0.045045
# 1        blues.00093.au   58.726918     26     0.377690  0.065906
# 2          pop.00049.au   58.726918     28     0.322574  0.147505
# 3      country.00061.au   60.092660     30     0.314423  0.107209
# 4         jazz.00007.au   61.523438     28     0.197231  0.093770
# ..                  ...         ...    ...          ...       ...
# 995  classical.00053.au  215.332031     95     0.304578  0.139884
# 996       jazz.00030.au  215.332031    102     0.235051  0.029619
# 997        pop.00076.au  215.332031    109     0.475726  0.245391
# 998       jazz.00017.au  215.332031    105     0.345524  0.049864
# 999  classical.00009.au  234.907670    117     0.270478  0.023798
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0          1787.800681         2485.583898  3905.418051            0.062758
# ...

# %%
#    정렬된 tempo 항목의 상위 25%와 하위 25%를 0으로 대체하여 훈련 데이터를 생성하고 
#    tempo 항목의 평균과 표준편차의 합을 구하시오. music.csv  R answer: 116.9999  Python answer: 116.92620848615249
df.loc[0:per25,'tempo']=0

# %%
df.loc[per75:,'tempo']=0

# %%
df['tempo'].mean()+df['tempo'].std()
# Out:
# 116.99992970578714

# %%
# 9. telco-customer-churn 데이터 세트이다. telco-customer-churn.csv
#    TotalCharges 항목에서 이상값을 제외한 평균을 구하시오.
#    (이상값은 평균에서 1.5 표준편차 이상인 값)  telco-customer-churn.csv  answer: 1663.9953

# %%
df=pd.read_csv('./data/telco-customer-churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ",0)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])

# %%
upper=df['TotalCharges'].mean()+1.5*df['TotalCharges'].std()
lower=df['TotalCharges'].mean()-1.5*df['TotalCharges'].std()

# %%
dd=df[(df['TotalCharges']>=upper)|(df['TotalCharges']<=lower)].index

# %%
df.drop(dd,inplace=True)

# %%
df['TotalCharges'].mean()
# Out:
# 1658.446577885392

# %%
# 10. 다음과 같이 고양이 cats의 데이터 세트가 주어질 경우에 심장의 무게(Hwt)의 이상값의 평균을 구하시오. cats.csv
#    (이상값은 평균에서 1.5배 표준편차를 벗어나는 값으로 한다.) ./data/cats.csv  answer: 13.94375

# %%
df=pd.read_csv('./data/cats.csv')

# %%
df
# Out:
#     Sex  Bwt   Hwt
# 0     F  2.0   7.0
# 1     F  2.0   7.4
# 2     F  2.0   9.5
# 3     F  2.1   7.2
# 4     F  2.1   7.3
# ..   ..  ...   ...
# 139   M  3.7  11.0
# 140   M  3.8  14.8
# 141   M  3.8  16.8
# 142   M  3.9  14.4
# 143   M  3.9  20.5
#
# [144 rows x 3 columns]

# %%
upper=df['Hwt'].mean()+df['Hwt'].std()*1.5
lower=df['Hwt'].mean()-df['Hwt'].std()*1.5

# %%
df[(df['Hwt']>upper)|(df['Hwt']<lower)]['Hwt'].mean()
# Out:
# 13.943750000000001

# %%
# 11. 주어진 데이터세트는 32개 자동차 모델의 디자인과 성능을 비교한 mtcars 내장 데이터 세트이다. mtcars.csv
#    수동(am=1) 중에서 가장 무게(wt)가 작게 나가는 10개 데이터의 평균 연비(mpg)와
#    자동(am=0) 중에서 가장 무게(wt)가 작게 나가는 10개 데이터의 평균 연비(mpg)의 차이를 구하시오. 
#   ./data/mtcars.csv  answer: 7.07

# %%
# 12. 주어진 diamonds의 데이터를 순서대로 80% 데이터를 제거한 후 diamonds.csv
#     cut이 'Fair' 이면서 carat이 1 이상인 diamonds의 price의 최댓값을 구하시오. 
#     ./data/diamonds.csv  answer: 2745

# %%
# 13. 다음은 airquality 데이터 세트이다. 8월 20일의 Ozone 값을 구하시오.  airquality.csv
#     ./data/airquality.csv  answer: 44

# %%
# 14. sepal.length의 mean 값과 sepal.width의 mean 값의 합계를구하시오.  iris.csv
#     ./data/iris.csv  answer: 8.900667

# %%
# 15. 다음은 mtcars 데이터 세트이다. 4기통(cyl)인 자동차의 백분율(%)을 구하시오.  mtcars.csv
#   ./data/mtcars.csv  answer: 34.375

# %%
# 16. 다음은 mtcars 데이터 세트이다.  mtcars.csv
#     변속 기어(gear) 수가 4이고 수동 변속기(am: 0 자동, 1 수동)인 데이터에서
#     자동차 연비(mpg)의 mean 값과 전체 마력(hp)의 표준편차의 합계를 구하시오. 
#     ./data/mtcars.csv  answer: 50.44959

# %%
# 17. 다음은 iris 데이터 세트이다.  iris.csv
#     iris 데이터 세트에서 variety가 virginica인 항목에서 
#     sepal.length가 6보다 크면 1, 아니면 0으로 파생컬럼 len을 생성 후
#     len컬럼의 sum 값을 구하시오. 
#     ./data/iris.csv  answer: 41

# %%
# 18. 다음은 airquality 데이터 세트이다.airquality.csv
#     Ozone의 결측값을 평균 값을 구한 값으로 대체하고,
#     median 값에서 2*IQR을 뺀 값과
#     median 값에서 2*IQR 더한 값 사이에 존재하는
#     Ozone 값의 합계를 구하시오. ./data/airquality.csv  answer: 5279.784

# %%
# 19. 다음은 FIFA Ranking 데이터 세트이다.   fifa.csv
#     총점수(total_points)가 상위 3위인 국가(country_abrv)를 하나 선택하고
#     이 국가의 총점수(total_points) 항목의 평균을 구하시오. ./data/fifa.csv  answer: 421.5051

# %%
# 20. 다음은 sales_train 데이터 세트이다.  sales.csv
#     가장 많이 판매된 상품(item_id) 3가지와 
#     전체 상품에 대하여 상품 판매가(item_price) 표준편차 차이를 구하시오. 
#     ./data/sales.csv  answer: 768.7317

# %%
#21. IRIS 데이터 세트에서 species 변수 값별로 petal_width 상위 25% 값을 구한 후,  iris.csv
#가장 큰 값과 가장 작은 값 사이의 차이를 구하시오.

# %%
#22. IRIS 데이터 세트에서 sepal.length 변수의 전체 값들을 중복 없이 리스트로 만든 후, iris.csv
#오름차순으로 정렬했을 때 리스트의 10번째에 오는 숫자를 계산하시오.
# answer: 5.2

# %%
# 23. IRIS 데이터 세트를 sepal.width 변수 값으로 내림차순한 후 위에서부터 100개 행을 학습 iris.csv
# 데이터로 분리하고, 학습 데이터에서 sepal.width의 표준편차 값을 구한 후 50을 곱한 값을 계산하시오.
# (최종 계산 값의 소수점 이하는 버린다.)
# answer: 16

# %%
# 24. IRIS 데이터 세트에서 species 변수 값별로 petal.length 상위 10개 행(큰 값)의 평균값을 구한 후, iris.csv
# 평균값의 합을 계산하시오(최종 계산 값의 소수점 이하는 반올림한다.)
# answer: 13

# %%
# 25. IRIS 데이터 세트에서 sepal.length 변수가 이상치를 가지는 데이터 행 수를 계산하시오 iris.csv
# (단, 이상치 범위는 (평균 + 2 x 표준편차)) 이상이거나 (평균 - 2 x 표준편차) 이하이다.)
# answer: 6

# %%
# 26. Wine 데이터 세트에서 total_phenols 결측치를 제거하고, wine.csv
# alcalinity_of_ash 변수의 결측치는 중앙값으로 대체한 후,
# alcalinity_of_ash 평균값을 계산하시오(최종 계산 값의 소수점 이하는 버린다).
# answer: 19

# %%
# 27. Wine 데이터 세트에서 alcohol 값이 alcohol 평균 값 이상이고,  wine.csv
# color_intensity 값이 color_intensity 평균 값이 상인 데이터만 남겼을 때, 가장 많은 class 값을 구하시오.
# answer: 0

# %%
# 28. Wine 데이터 세트에서 class 1에 해당하는 데이터의 ash 평균값과 wine.csv
# Wine 데이터 세트의 모든 결측치를 제거한 후의
# ash 값의 평균값의 차이의 절댓값을 계산하시오(최종 계산 값의 소수점 아래 4번째 자리에서 반올림한다.).
# answer: 0.12

# %%
# 29. Wine 데이터 세트에서 alcohol변수를 오름차순 정렬했을 때,  wine.csv
# 20번째에 위치한 값으로 상위 20개의 값을 변환한 후,
# proanthocyanins가 2 이하인 데이터를 추출하여 alcohol의 평균값을 계산하시오.
# (최종 계산 값의 소수점 아래 3번째 자리에서 반올림한다.).
# answer: 12.97

# %%
# 30. Wine 데이터 세트에서 class 1에 해당하는 데이터의 wine.csv
# proline 변수의 제 3사분위수와 제 1사분위수 차를 구하고,
# class 2에 해당하는 데이터의 proline 변수의 제3사분위수와 제 1사분위수 차를 구하여
# 두 값의 차이의 절댓값을 계산하시오.
# answer: 68.5
