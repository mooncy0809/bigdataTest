# %% [markdown]
# # 하루삼끼 추천시스템 2
# ## Hidden layer를 사용하는 Keras 기반의 MF(Matrix Factorization, 행렬 요인화) 구현
# - 평가가 적음으로 평점이 적게 학습됨으로 평균을 사전에 파악한후 예측 결과에 추가하여 평점을 높임.

# %%
import os
import time

import pandas as pd
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam    # 가중치, bias 최적화

# csv 파일에서 불러오기
r_cols = ['memberno', 'productno', 'rating'] # 사용자 아이디, 아이템 아이디, 평점 데이터
ratings = pd.read_csv('u.data', names=r_cols,  sep=',', encoding='utf-8')
ratings = ratings[['memberno', 'productno', 'rating']].astype(int)            # timestamp 제거

# train test 분리
from sklearn.utils import shuffle

TRAIN_SIZE = 0.75
ratings = shuffle(ratings) # DataFrame형태의 데이터를 무작위로 섞음
cutoff = int(TRAIN_SIZE * len(ratings))
print('cutoff:', cutoff)
ratings_train = ratings.iloc[:cutoff] # 0:75000b
ratings_test = ratings.iloc[cutoff:]  # 75000:100000
# Out:
# cutoff: 225

# %%
# u.item 파일을 DataFrame으로 읽기
i_cols = ['productno', 'name', 'cate1','cate2','cate3','cate4','cate5']
products = pd.read_csv('u.item', sep=',', names=i_cols, encoding='utf-8')
products = products.set_index('productno')
products.head()
# Out:
#                        name  cate1  cate2  cate3  cate4  cate5
# productno
# 1          맛있닭 닭가슴살 소시지 훈제맛      1      0      0      0      0
# 2            잇메이트 저염 훈제닭가슴살      1      0      0      0      0
# 3             아워홈 참나무향 닭가슴살      1      0      0      0      0
# 4           러브잇 닭가슴살 짜장 매운맛      1      0      0      0      0
# 5           굽네 훈제 닭가슴살 오리지널      1      0      0      0      0

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dot, Add, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adamax
from tensorflow.keras.callbacks import EarlyStopping   # 학습 자동 중지
from tensorflow.keras.callbacks import ModelCheckpoint # 우수한 학습 모델 파일 저장

# %%
print(ratings.memberno.max())
print(ratings.memberno.max()+1) 
print(ratings.productno.max())
print(ratings.productno.max()+1)
# Out:
# 50
# 51
# 25
# 26

# %%
# Variable 초기화 
K = 100                             # Latent factor 수, 잠재 요인수 
mu = ratings_train.rating.mean()    # 전체 평균, 연산의 규모를 줄이기 위하여  
M = ratings.memberno.max() + 1       # Number of members
N = ratings.productno.max() + 1      # Number of products

# %%
# Keras model
user = Input(shape=(1, ))                                               # User input
item = Input(shape=(1, ))                                               # Item input
# Embedding(입력차원, 출력차원, 정규화 알고리즘)
P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user)        # (M, 1, K)
print(P_embedding.shape)
Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item)        # (N, 1, K)
print(Q_embedding.shape)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user)          # User bias term (M, 1, )
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item)          # Item bias term (N, 1, )
# Out:
# (None, 1, 100)
# (None, 1, 100)

# %%
# layers.dot
x = np.arange(4).reshape(2, 2)
print(x)
y = np.arange(4).reshape(2, 2)
print(y)
# Out:
# [[0 1]
#  [2 3]]
# [[0 1]
#  [2 3]]

# %%
# 0 * 0 + 1 * 1, 2 * 2 + 3 * 3
layers.dot([x, y], axes=1) # 0 지원 안함, 1: 행우선(행단위) 연산
# Out:
# <tf.Tensor: shape=(2, 1), dtype=int32, numpy=
# array([[ 1],
#        [13]])>

# %%
# layers.dot([x, y], axes=2) # ERROR, 2: 행우선(행단위) 연산
x = np.arange(3).reshape(1, 1, 3)
print(x)
y = np.arange(3).reshape(1, 1, 3)
print(y)
# Out:
# [[[0 1 2]]]
# [[[0 1 2]]]

# %%
layers.dot([x, y], axes=1)
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=int32, numpy=
# array([[[0, 0, 0],
#         [0, 1, 2],
#         [0, 2, 4]]])>

# %%
layers.dot([x, y], axes=2) # 열우선 연산
# Out:
# <tf.Tensor: shape=(1, 1, 1), dtype=int32, numpy=array([[[5]]])>

# %%
# Concatenate layers
from tensorflow.keras.layers import Dense, Concatenate, Activation
P_embedding = Flatten()(P_embedding)                                    # (K, )
Q_embedding = Flatten()(Q_embedding)                                    # (K, )
user_bias = Flatten()(user_bias)                                        # (1, )
item_bias = Flatten()(item_bias)                                        # (1, )
R = Concatenate()([P_embedding, Q_embedding, user_bias, item_bias])     # (2K + 2, )

# %%
# Neural network
R = Dense(2048)(R)
R = Activation('linear')(R)
R = Dense(256)(R)
R = Activation('linear')(R)
R = Dense(1)(R)

# %%
model = Model(inputs=[user, item], outputs=R)
model.compile(loss='mse', optimizer=Adam(lr=0.01),metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 100)       5100        ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 100)       2600        ['input_2[0][0]']
#
#  embedding_2 (Embedding)        (None, 1, 1)         51          ['input_1[0][0]']
#
#  embedding_3 (Embedding)        (None, 1, 1)         26          ['input_2[0][0]']
#
#  flatten (Flatten)              (None, 100)          0           ['embedding[0][0]']
#
#  flatten_1 (Flatten)            (None, 100)          0           ['embedding_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 1)            0           ['embedding_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 1)            0           ['embedding_3[0][0]']
#
#  concatenate (Concatenate)      (None, 202)          0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  dense (Dense)                  (None, 2048)         415744      ['concatenate[0][0]']
#
#  activation (Activation)        (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 256)          524544      ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 256)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            257         ['activation_1[0][0]']
#
# ==================================================================================================
# Total params: 948,322
# Trainable params: 948,322
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
es = EarlyStopping(patience=10, restore_best_weights=True)

start = time.time()
result = model.fit(
  x=[ratings_train.memberno.values, ratings_train.productno.values],
  y=ratings_train.rating.values - mu,
  epochs=30, batch_size=30,
  validation_data=(
    [ratings_test.memberno.values, ratings_test.productno.values], ratings_test.rating.values - mu
  ), 
  callbacks=[es]
)
end = time.time()
print('Runtime: {0:.2f} 초'.format(end-start))
# Out:
# Epoch 1/30
# 8/8 [==============================] - 2s 61ms/step - loss: 6.4316 - mse: 6.3792 - val_loss: 3.8269 - val_mse: 3.7574
# Epoch 2/30
# 8/8 [==============================] - 0s 21ms/step - loss: 2.2837 - mse: 2.1974 - val_loss: 2.0680 - val_mse: 1.9602
# Epoch 3/30
# 8/8 [==============================] - 0s 25ms/step - loss: 1.7480 - mse: 1.6295 - val_loss: 1.5697 - val_mse: 1.4380
# Epoch 4/30
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3724 - mse: 1.2348 - val_loss: 2.5523 - val_mse: 2.4082
# Epoch 5/30
# 8/8 [==============================] - 0s 27ms/step - loss: 1.4228 - mse: 1.2773 - val_loss: 1.5523 - val_mse: 1.4061
# Epoch 6/30
# 8/8 [==============================] - 0s 36ms/step - loss: 1.1852 - mse: 1.0394 - val_loss: 1.4776 - val_mse: 1.3331
# Epoch 7/30
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1714 - mse: 1.0289 - val_loss: 1.8093 - val_mse: 1.6698
# Epoch 8/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.1115 - mse: 0.9743 - val_loss: 1.5446 - val_mse: 1.4105
# Epoch 9/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0697 - mse: 0.9374 - val_loss: 1.8096 - val_mse: 1.6800
# Epoch 10/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0996 - mse: 0.9721 - val_loss: 1.5305 - val_mse: 1.4057
# Epoch 11/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.1140 - mse: 0.9912 - val_loss: 1.4733 - val_mse: 1.3543
# Epoch 12/30
# 8/8 [==============================] - 0s 22ms/step - loss: 1.1972 - mse: 1.0803 - val_loss: 2.1103 - val_mse: 1.9961
# Epoch 13/30
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1565 - mse: 1.0456 - val_loss: 1.4445 - val_mse: 1.3385
# Epoch 14/30
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1999 - mse: 1.0957 - val_loss: 1.6422 - val_mse: 1.5405
# Epoch 15/30
# 8/8 [==============================] - 0s 30ms/step - loss: 1.1033 - mse: 1.0027 - val_loss: 1.6505 - val_mse: 1.5503
# Epoch 16/30
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0942 - mse: 0.9946 - val_loss: 1.5264 - val_mse: 1.4296
# Epoch 17/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0913 - mse: 0.9959 - val_loss: 1.7447 - val_mse: 1.6504
# Epoch 18/30
# 8/8 [==============================] - 0s 22ms/step - loss: 1.0705 - mse: 0.9769 - val_loss: 1.5651 - val_mse: 1.4726
# Epoch 19/30
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0150 - mse: 0.9233 - val_loss: 1.5993 - val_mse: 1.5087
# Epoch 20/30
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0285 - mse: 0.9388 - val_loss: 1.5065 - val_mse: 1.4195
# Epoch 21/30
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0527 - mse: 0.9670 - val_loss: 1.7950 - val_mse: 1.7103
# Epoch 22/30
# 8/8 [==============================] - 0s 31ms/step - loss: 1.1255 - mse: 1.0425 - val_loss: 1.3964 - val_mse: 1.3175
# Epoch 23/30
# 8/8 [==============================] - 0s 26ms/step - loss: 1.1015 - mse: 1.0241 - val_loss: 1.3610 - val_mse: 1.2868
# Epoch 24/30
# 8/8 [==============================] - 0s 29ms/step - loss: 1.0831 - mse: 1.0104 - val_loss: 2.1948 - val_mse: 2.1238
# Epoch 25/30
# 8/8 [==============================] - 0s 33ms/step - loss: 1.1513 - mse: 1.0815 - val_loss: 1.3890 - val_mse: 1.3210
# Epoch 26/30
# 8/8 [==============================] - 0s 30ms/step - loss: 1.1011 - mse: 1.0326 - val_loss: 1.5869 - val_mse: 1.5189
# Epoch 27/30
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0881 - mse: 1.0215 - val_loss: 1.4542 - val_mse: 1.3881
# Epoch 28/30
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0764 - mse: 1.0099 - val_loss: 1.7410 - val_mse: 1.6748
# Epoch 29/30
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0295 - mse: 0.9638 - val_loss: 1.4360 - val_mse: 1.3699
# Epoch 30/30
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0344 - mse: 0.9682 - val_loss: 1.7824 - val_mse: 1.7155
# Runtime: 7.72 초

# %%
model.save('./personalization_mu_mlp2.h5')

# %%
import matplotlib.pyplot as plt
plt.plot(result.history['loss'], label="Train loss")
plt.plot(result.history['val_loss'], label="Test loss")
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13624\203901968.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(result.history['loss'], label="Train loss")
#       3 plt.plot(result.history['val_loss'], label="Test loss")
#       4 plt.xlabel('epoch')
#       5 plt.ylabel('MSE')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 테스트 데이터 Prediction
user_ids = ratings_test.memberno.values[0:6]
movie_ids = ratings_test.productno.values[0:6]
predictions = model.predict([user_ids, movie_ids]) + mu
print("Actuals: \n", ratings_test[0:6])
print( )
print("Predictions: \n", predictions)
# Out:
# 1/1 [==============================] - 0s 173ms/step
# Actuals:
#       memberno  productno  rating
# 194        20         19       4
# 114        33          9       4
# 272        33         20       4
# 150         1         10       4
# 245         2          4       4
# 42         10         11       2
#
# Predictions:
#  [[2.4893556]
#  [3.27747  ]
#  [4.411018 ]
#  [3.0096974]
#  [3.793476 ]
#  [4.9037437]]

# %%
df6 = ratings_test[0:6]
df6
# Out:
#      memberno  productno  rating
# 194        20         19       4
# 114        33          9       4
# 272        33         20       4
# 150         1         10       4
# 245         2          4       4
# 42         10         11       2

# %%
# print(type(predictions))
df6['predictions'] = predictions
df6
# Out:
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      memberno  productno  rating  predictions
# 194        20         19       4     2.489356
# 114        33          9       4     3.277470
# 272        33         20       4     4.411018
# 150         1         10       4     3.009697
# 245         2          4       4     3.793476
# 42         10         11       2     4.903744

# %%
ratings_test[0:6]
# Out:
#      memberno  productno  rating
# 194        20         19       4
# 114        33          9       4
# 272        33         20       4
# 150         1         10       4
# 245         2          4       4
# 42         10         11       2

# %%
df6.sort_values('predictions', ascending=False, inplace=True)
df6
# Out:
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      memberno  productno  rating  predictions
# 42         10         11       2     4.903744
# 272        33         20       4     4.411018
# 245         2          4       4     3.793476
# 114        33          9       4     3.277470
# 150         1         10       4     3.009697
# 194        20         19       4     2.489356

# %%
# Prediction
user_ids = ratings_test.memberno.values
print(type(user_ids))
print(user_ids.shape)
product_ids = ratings_test.productno.values
predictions = model.predict([user_ids, product_ids]) + mu
print("Actuals: \n", ratings_test[0:6])
print( )
print("Predictions: \n", predictions)
# Out:
# <class 'numpy.ndarray'>
# (75,)
# 3/3 [==============================] - 0s 5ms/step
# Actuals:
#       memberno  productno  rating
# 194        20         19       4
# 114        33          9       4
# 272        33         20       4
# 150         1         10       4
# 245         2          4       4
# 42         10         11       2
#
# Predictions:
#  [[2.4893556 ]
#  [3.27747   ]
#  [4.411018  ]
#  [3.0096972 ]
#  [3.793476  ]
#  [4.9037437 ]
#  [3.2389398 ]
#  [3.7300603 ]
#  [0.99938893]
#  [4.020634  ]
#  [2.4561076 ]
#  [4.3779297 ]
#  [2.85236   ]
#  [3.3957129 ]
#  [3.3455896 ]
#  [3.7664096 ]
#  [4.1647596 ]
#  [4.1647596 ]
#  [4.9967613 ]
#  [4.1339197 ]
#  [2.3172703 ]
#  [4.0215983 ]
#  [2.8126326 ]
#  [3.7878873 ]
#  [3.692148  ]
#  [3.6850362 ]
#  [2.341914  ]
#  [3.425059  ]
#  [3.9591405 ]
#  [4.794595  ]
#  [3.6101255 ]
#  [2.9324057 ]
#  [3.9615521 ]
#  [2.1434674 ]
#  [3.7527053 ]
#  [4.16829   ]
#  [2.7371883 ]
#  [4.6923213 ]
#  [2.6411486 ]
#  [4.869233  ]
#  [1.9710778 ]
#  [2.9324057 ]
#  [3.0700362 ]
#  [4.5402536 ]
#  [3.4487984 ]
#  [4.9624143 ]
#  [3.4471493 ]
#  [2.851757  ]
#  [3.040804  ]
#  [3.023727  ]
#  [2.6690967 ]
#  [3.7386029 ]
#  [3.2840261 ]
#  [2.766841  ]
#  [3.1764276 ]
#  [3.1551123 ]
#  [3.4071841 ]
#  [4.2453537 ]
#  [4.1570415 ]
#  [3.1149254 ]
#  [4.877057  ]
#  [2.8164978 ]
#  [2.542366  ]
#  [4.6261353 ]
#  [3.1272602 ]
#  [5.0357647 ]
#  [3.8597143 ]
#  [2.8555512 ]
#  [3.5699542 ]
#  [5.270503  ]
#  [2.7461963 ]
#  [2.7371883 ]
#  [2.6296372 ]
#  [3.6140423 ]
#  [2.4969852 ]]

# %%
df = ratings_test.copy()
# print(type(predictions))
df['predictions'] = predictions
df.sort_values('predictions', ascending=False, inplace=True)
df.head(10)
# Out:
#      memberno  productno  rating  predictions
# 291        37          2       4     5.270503
# 237        42         13       2     5.035765
# 231        37         16       5     4.996761
# 207         9         15       3     4.962414
# 42         10         11       2     4.903744
# 218        10          7       5     4.877057
# 142         4         17       2     4.869233
# 203        32          8       4     4.794595
# 80         23          1       5     4.692321
# 151        27         20       3     4.626135

# %%
df[df['memberno'] == 30].head(10)
# Out:
#      memberno  productno  rating  predictions
# 219        30         13       2     2.812633
# 155        30         19       4     2.456108
# 160        30         23       3     2.341914

# %% [markdown]
# ### 개별 회원 추천

# %%
# 모델 로딩
model = load_model('./personalization_mu_mlp.h5')

# 상품 로딩
i_cols = ['productno', 'name', 'cate1','cate2','cate3','cate4','cate5']
products = pd.read_csv('u.item', sep=',', names=i_cols, encoding='utf-8')
products = products.set_index('productno')
display(products.head())

# 평점 로딩
r_cols = ['memberno', 'productno', 'rating'] # 사용자 아이디, 아이템 아이디, 평점 데이터
ratings = pd.read_csv('u.data', names=r_cols,  sep=',', encoding='utf-8')
ratings = ratings[['memberno', 'productno', 'rating']].astype(int)            # timestamp 제거
display(ratings.head())
# Out:
#                        name  cate1  cate2  cate3  cate4  cate5
# productno
# 1          맛있닭 닭가슴살 소시지 훈제맛      1      0      0      0      0
# 2            잇메이트 저염 훈제닭가슴살      1      0      0      0      0
# 3             아워홈 참나무향 닭가슴살      1      0      0      0      0
# 4           러브잇 닭가슴살 짜장 매운맛      1      0      0      0      0
# 5           굽네 훈제 닭가슴살 오리지널      1      0      0      0      0
#    memberno  productno  rating
# 0         4         19       3
# 1        30         13       3
# 2         8         21       1
# 3        26         23       2
# 4        29         24       1

# %%
# 아직 구매하지 않은 상품 리스트 함수
def get_unorder(ratings, products, memberno):
     # 특정 user_id가 평점을 매긴 모든 상품 리스트
    order_products = ratings[ratings['memberno']== memberno]['productno'].tolist()
    
    # 모든 상품 list 객체로 만듬. 
    total_products = products.index.tolist()
      
    # 한줄 for + if문으로 구매하지 않은 상품 리스트 생성
    unorder_products = [ product for product in total_products if product not in order_products]
    
    total_product_cnt = len(total_products) # 모든 상품수
    order_cnt = len(order_products)         # 주문한 상품수
    unorder_cnt = len(unorder_products)     # 주문하지 않은 상품수
    
    print(f"전체 상품 수: {total_product_cnt}, 평점 매긴 상품 수: {order_cnt}, 추천 대상 상품 수: {unorder_cnt}")
    
    return unorder_products

# %%
memberno = int(input('회원 번호를 입력하세요(3-50):'))
unorder_products = get_unorder(ratings, products, memberno)
# Out:
# 회원 번호를 입력하세요(3-50):30
# 전체 상품 수: 25, 평점 매긴 상품 수: 7, 추천 대상 상품 수: 19

# %%
user_ids = np.array([memberno] * 19)
print(user_ids)
product_ids = np.array(unorder_products)
print(product_ids)
print(mu)
# Out:
# [30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30]
# [ 1  2  3  4  6  7  8  9 10 11 12 14 15 16 17 18 20 21 25]
# 3.56

# %%
print(len(unorder_products))
user_ids = np.array([memberno] * 19)
print(type(user_ids))
print(user_ids.shape)
product_ids = np.array(unorder_products)
print(product_ids.shape)
predictions = model.predict([user_ids, product_ids]) + mu
display(predictions[:5,0])
# Out:
# 19
# <class 'numpy.ndarray'>
# (19,)
# (19,)
# 1/1 [==============================] - 0s 89ms/step
# array([3.9272854, 3.41038  , 3.2854269, 3.6819966, 3.779529 ],
#       dtype=float32)

# %%
user_ids_df = pd.DataFrame(user_ids).rename(columns={0:'user_id'})
user_ids_df.head()
# Out:
#    user_id
# 0       30
# 1       30
# 2       30
# 3       30
# 4       30

# %%
product_ids_df = pd.DataFrame(product_ids).rename(columns={0:'productno'})
product_ids_df.head()
# Out:
#    productno
# 0          1
# 1          2
# 2          3
# 3          4
# 4          6

# %%
product_ids_df = pd.DataFrame(product_ids).rename(columns={0:'productno'})
product_ids_df.head()
# Out:
#    productno
# 0          1
# 1          2
# 2          3
# 3          4
# 4          6

# %%
predictions_df = pd.DataFrame(predictions).rename(columns={0:'prediction'})
predictions_df.head()
# Out:
#    prediction
# 0    3.927285
# 1    3.410380
# 2    3.285427
# 3    3.681997
# 4    3.779529

# %%
df = pd.concat([user_ids_df, product_ids_df, predictions_df], axis=1)
df.head()
# Out:
#    user_id  productno  prediction
# 0       30          1    3.927285
# 1       30          2    3.410380
# 2       30          3    3.285427
# 3       30          4    3.681997
# 4       30          6    3.779529

# %%
df.sort_values(['prediction'], ascending=False, inplace=True)
df.head()
# Out:
#     user_id  productno  prediction
# 10       30         12    4.508786
# 6        30          8    4.182733
# 11       30         14    4.174152
# 7        30          9    4.055599
# 8        30         10    3.951944

# %%
product_ids = df['productno']
print(product_ids)
# Out:
# 10    12
# 6      8
# 11    14
# 7      9
# 8     10
# 9     11
# 0      1
# 5      7
# 12    15
# 4      6
# 3      4
# 16    20
# 18    25
# 13    16
# 1      2
# 2      3
# 14    17
# 17    21
# 15    18
# Name: productno, dtype: int32

# %%
print(type(df['prediction']))
print(df['prediction'])
# Out:
# <class 'pandas.core.series.Series'>
# 10    4.508786
# 6     4.182733
# 11    4.174152
# 7     4.055599
# 8     3.951944
# 9     3.949545
# 0     3.927285
# 5     3.910068
# 12    3.870086
# 4     3.779529
# 3     3.681997
# 16    3.662662
# 18    3.577274
# 13    3.424046
# 1     3.410380
# 2     3.285427
# 14    3.217551
# 17    3.068177
# 15    3.001008
# Name: prediction, dtype: float32

# %%
recom_df = products.loc[df['productno']]
recom_df.head(6)
# Out:
#                                         name  cate1  cate2  cate3  cate4  \
# productno
# 12                  밥보다 샐러드 닭가슴살햄슬라이스&스모크드치즈      0      0      1      0
# 8                       밀스원 탄두리치킨볶음밥 & 참치오믈렛      0      1      0      0
# 14                               수비드닭가슴살빅샐러드      0      0      1      0
# 9             맛있닭 더담은 도시락 닭가슴살 큐브마늘맛 & 연근우엉밥      0      1      0      0
# 10         더 담아 꽉~채운 계란야채곤약볶음밥&토마토소스닭가슴살슬라이스      0      1      0      0
# 11                            포켓샐러드 닭가슴살 샐러드      0      0      1      0
#
#            cate5
# productno
# 12             0
# 8              0
# 14             0
# 9              0
# 10             0
# 11             0

# %%
recom_df['prediction'] = np.array(df['prediction'])
recom_df
# Out:
#                                         name  cate1  cate2  cate3  cate4  \
# productno
# 12                  밥보다 샐러드 닭가슴살햄슬라이스&스모크드치즈      0      0      1      0
# 8                       밀스원 탄두리치킨볶음밥 & 참치오믈렛      0      1      0      0
# 14                               수비드닭가슴살빅샐러드      0      0      1      0
# 9             맛있닭 더담은 도시락 닭가슴살 큐브마늘맛 & 연근우엉밥      0      1      0      0
# 10         더 담아 꽉~채운 계란야채곤약볶음밥&토마토소스닭가슴살슬라이스      0      1      0      0
# 11                            포켓샐러드 닭가슴살 샐러드      0      0      1      0
# 1                           맛있닭 닭가슴살 소시지 훈제맛      1      0      0      0
# 7                        잇메이트 닭가슴살소세지볶음밥 마늘맛      0      1      0      0
# 15                       아임닭 23 단백질 닭가슴살 샐러드      0      0      1      0
# 6                      맛있닭 닭가슴살 한끼 곤약볶음밥 양송이      0      1      0      0
# 4                            러브잇 닭가슴살 짜장 매운맛      1      0      0      0
# 20                                 유산균슬림다이어트      0      0      0      1
# 25                              단백질공화국 다크초콜릿      0      0      0      0
# 16                                애터미 밸런스라이프      0      0      0      1
# 2                             잇메이트 저염 훈제닭가슴살      1      0      0      0
# 3                              아워홈 참나무향 닭가슴살      1      0      0      0
# 17                                    린 컴플리트      0      0      0      1
# 21                               성수동 스무디 오트밀      0      0      0      0
# 18                         HOPE 발효효소 밸런스밀 블랙      0      0      0      1
#
#            cate5  prediction
# productno
# 12             0    4.508786
# 8              0    4.182733
# 14             0    4.174152
# 9              0    4.055599
# 10             0    3.951944
# 11             0    3.949545
# 1              0    3.927285
# 7              0    3.910068
# 15             0    3.870086
# 6              0    3.779529
# 4              0    3.681997
# 20             0    3.662662
# 25             1    3.577274
# 16             0    3.424046
# 2              0    3.410380
# 3              0    3.285427
# 17             0    3.217551
# 21             1    3.068177
# 18             0    3.001008

# %%
def recomm_product(model, memberno, unorder_products, top_n=10, mu=3.56):
    user_ids = np.array([memberno] * len(unorder_products))
    product_ids = np.array(unorder_products)
    predictions = model.predict([user_ids, product_ids]) + mu
    display(predictions[:5,0])
    
    user_ids_df = pd.DataFrame(user_ids).rename(columns={0:'memberno'})
    product_ids_df = pd.DataFrame(product_ids).rename(columns={0:'productno'})
    predictions_df = pd.DataFrame(predictions).rename(columns={0:'prediction'})
    df = pd.concat([user_ids_df, product_ids_df, predictions_df], axis=1)
    df.sort_values(['prediction'], ascending=False, inplace=True)
    
    df_sub = df.head(top_n)
    recom_df = products.loc[df_sub['productno']]
    recom_df['prediction'] = np.array(df_sub['prediction'])
    
    return recom_df[['name', 'prediction']]

# %%
mu = 3.56
model = load_model('./personalization_mu_mlp.h5')
user_id = int(input('회원 번호를 입력하세요(1):')) # 1
unorder_products = get_unorder(ratings, products, memberno)
df = recomm_product(model, memberno, unorder_products, 10, mu)
display(df)
# Out:
# 회원 번호를 입력하세요(1):30
# 전체 상품 수: 25, 평점 매긴 상품 수: 7, 추천 대상 상품 수: 19
# 1/1 [==============================] - 0s 209ms/step
# array([3.9272854, 3.41038  , 3.2854269, 3.6819966, 3.779529 ],
#       dtype=float32)
#                                         name  prediction
# productno
# 12                  밥보다 샐러드 닭가슴살햄슬라이스&스모크드치즈    4.508786
# 8                       밀스원 탄두리치킨볶음밥 & 참치오믈렛    4.182733
# 14                               수비드닭가슴살빅샐러드    4.174152
# 9             맛있닭 더담은 도시락 닭가슴살 큐브마늘맛 & 연근우엉밥    4.055599
# 10         더 담아 꽉~채운 계란야채곤약볶음밥&토마토소스닭가슴살슬라이스    3.951944
# 11                            포켓샐러드 닭가슴살 샐러드    3.949545
# 1                           맛있닭 닭가슴살 소시지 훈제맛    3.927285
# 7                        잇메이트 닭가슴살소세지볶음밥 마늘맛    3.910068
# 15                       아임닭 23 단백질 닭가슴살 샐러드    3.870086
# 6                      맛있닭 닭가슴살 한끼 곤약볶음밥 양송이    3.779529

# %%
model1 = load_model('./personalization_mu_mlp.h5')
model2 = load_model('./personalization_mu_mlp2.h5')
